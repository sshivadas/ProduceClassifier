# %%
from MyImports import *
from DAUtils import examine_dataset, visualize_sample_image, image_cnt_distribution_per_class

# %%
train_path = Path('./images/train')
test_path = Path('./images/test')

# %%
train_class_images, train_class_image_cnt = examine_dataset(train_path)
# Out:
# ✅ Class 'indian market' has 599 images.
# ✅ Class 'onion' has 849 images.
# ✅ Class 'potato' has 898 images.
# ✅ Class 'tomato' has 789 images.

# %%
test_class_images, test_class_image_cnt= examine_dataset(test_path)
# Out:
# ✅ Class 'indian market' has 81 images.
# ✅ Class 'onion' has 83 images.
# ✅ Class 'potato' has 81 images.
# ✅ Class 'tomato' has 106 images.

# %%
# Visualize renadom sample from each class in train
visualize_sample_image(train_class_images)

# %%
# Visualize renadom sample from each class in test
visualize_sample_image(test_class_images)

# %%
#Image distribution in train dataset
image_cnt_distribution_per_class(train_class_image_cnt)

# %%
#Image distribution in train dataset
image_cnt_distribution_per_class(test_class_image_cnt)

# %% [markdown]
# """
# 1.	Minor class imbalance exists in train data.
# 2.	Due to varying dimensions, images need to be resized to a consistent shape to be compatible with the model.
# 3.	The count of images loaded in runtime matches with the number of images in the given data.
#
# """
